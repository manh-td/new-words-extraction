# %%
from pathlib import Path
import json

path = Path(".")
for file in path.glob(".json"):
    content = json.loads(file.read_text())
    if len(content.get("part_of_speech")) < 0:
        print("part_of_speech")
